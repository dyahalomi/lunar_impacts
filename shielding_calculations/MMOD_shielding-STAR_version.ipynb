# %%
import numpy as np
import matplotlib.pyplot as plt


import matplotlib 
matplotlib.rc('xtick', labelsize=23) 
matplotlib.rc('ytick', labelsize=23)

# %%
t_w = 0.48
rho_b = 2.851
sigma = 52
S = 11.43
F_2 = 1
rho_p = 8.9
theta = 0

# V is the velocity, lets have it range from 10 to 85 km/s,
# look up the np.arange function to figure out how to do this!

#hint: V = ???

# %% [markdown]
# $d_c = 3.918 \, F_2  \, \frac{t_w^{2/3} S^{1/3} (\sigma/70)^{1/3}}{\rho_p^{1/3} \rho_b^{1/9} (V \cos \theta)^{2/3}}$

# %%
# now let's define d_c based on the function in the intro paper

#hint: d_c = ????

# %%
plt.figure(figsize = [18,9])

# now plot d_c vs. V, with V on the x-axis and d_c on the y-axis
#hint: plt.plot(???)


plt.ylabel("critical diamter [cm]", fontsize = 23)
plt.xlabel("velocity [km/s]", fontsize = 23)
plt.title("Ballistic Limit Curve for Whipple Shield", fontsize = 27)


plt.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np



# Value where the vertical line is to be added
velocity_value = 72

# Find the corresponding critical diameter for velocity = 72 km/s

# using the np.interp function, define critical_diameter...
# hint: the place where velocity_value intersects with the curve
# defined by V and d_c

#hint: critical_diameter = np.interp(???)

# Plot the ballistic limit curve
plt.figure(figsize=[18, 9])
# add the same plotting function from above
# hint: plt.plot(???)

# Add the vertical line at velocity = 72 km/s
plt.axvline(x=velocity_value, color='k', linestyle='--', lw=4)
# Annotate the vertical line with velocity label
plt.text(velocity_value - 0.5, plt.ylim()[1] * 0.5, f'Velocity = {velocity_value} km/s', 
         color='k', fontsize=18, rotation=90, va='center', ha='right')

# Annotate the critical diameter value on the curve
plt.plot(velocity_value, critical_diameter, color='k', zorder=3, marker='o', ms=18)
plt.text(velocity_value + 1, critical_diameter + 0.01, r'$r_{\mathrm{crit}} = $' + f'{critical_diameter:.2f} cm', fontsize=18, color='k')


# Fill areas below the curve in green and above the curve in red
plt.fill_between(V, d_c, plt.ylim()[0], color='green', alpha=0.3)
plt.fill_between(V, d_c, plt.ylim()[1], color='red', alpha=0.3)



# Labels and title
plt.ylabel("Critical Diameter [cm]", fontsize=23)
plt.xlabel("Velocity [km/s]", fontsize=23)
plt.title("Ballistic Limit Curve for Whipple Shield", fontsize=27)

plt.xlim(10,82)
plt.ylim(.1,.4)

# Layout and save
plt.tight_layout()
#plt.savefig('ballistic_curve.pdf')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/9z/bcj7jltn3x5_8y20r9cxql3h0000gn/T/ipykernel_26790/2516584057.py in <module>
#      27
#      28 # Annotate the critical diameter value on the curve
# ---> 29 plt.plot(velocity_value, critical_diameter, color='k', zorder=3, marker='o', ms=18)
#      30 plt.text(velocity_value + 1, critical_diameter + 0.01, r'$r_{\mathrm{crit}} = $' + f'{critical_diameter:.2f} cm', fontsize=18, color='k')
#      31
#
# NameError: name 'critical_diameter' is not defined
